# %% [markdown]
# ### Loops

# %%
if __name__ == '__main__':
    n = int(input()) # 5
    
    if n >= 0:
        for i in range(n):
            print(i*i)
    else:
        print("Enter Positive Input")
# Out:
# 0
# 1
# 4
# 9
# 16
